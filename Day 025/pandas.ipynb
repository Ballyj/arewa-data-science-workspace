# %%
# Exercise for pandas

import pandas as pd
import numpy as np
# Read the hacker news csv file
df = pd.read_csv("./result.csv")
# Get the first five rows
df.head()
# Out:
#                             highlights/0/description highlights/0/title  \
# 0  Companies are ranked by total revenues for the...      Revenues ($M)
# 1  Companies are ranked by total revenues for the...      Revenues ($M)
# 2  Companies are ranked by total revenues for the...      Revenues ($M)
# 3  Companies are ranked by total revenues for the...      Revenues ($M)
# 4  Companies are ranked by total revenues for the...      Revenues ($M)
#
#    highlights/0/value                           highlights/1/description  \
# 0              485873  Increase/decrease in revenues between the curr...
# 1              315199  Increase/decrease in revenues between the curr...
# 2              267518  Increase/decrease in revenues between the curr...
# 3              262573  Increase/decrease in revenues between the curr...
# 4              254694  Increase/decrease in revenues between the curr...
#
#   highlights/1/title  highlights/1/value  \
# 0     Revenue Change                 0.8
# 1     Revenue Change                -4.4
# 2     Revenue Change                -9.1
# 3     Revenue Change               -12.3
# 4     Revenue Change                 7.7
#
#                             highlights/2/description highlights/2/title  \
# 0  Net income after extraordinary charges for a c...       Profits ($M)
# 1  Net income after extraordinary charges for a c...       Profits ($M)
# 2  Net income after extraordinary charges for a c...       Profits ($M)
# 3  Net income after extraordinary charges for a c...       Profits ($M)
# 4  Net income after extraordinary charges for a c...       Profits ($M)
#
#    highlights/2/value                           highlights/3/description  ...  \
# 0             13643.0  Total assets on a company's fiscal year-end ba...  ...
# 1              9571.3  Total assets on a company's fiscal year-end ba...  ...
# 2              1257.9  Total assets on a company's fiscal year-end ba...  ...
# 3              1867.5  Total assets on a company's fiscal year-end ba...  ...
# 4             16899.3  Total assets on a company's fiscal year-end ba...  ...
#
#       tables/2/data/0/name  tables/2/data/0/value    tables/2/data/1/name  \
# 0  Profit as % of Revenues                    2.8  Profits as % of Assets
# 1  Profit as % of Revenues                    3.0  Profits as % of Assets
# 2  Profit as % of Revenues                    0.5  Profits as % of Assets
# 3  Profit as % of Revenues                    0.7  Profits as % of Assets
# 4  Profit as % of Revenues                    6.6  Profits as % of Assets
#
#   tables/2/data/1/value                tables/2/data/2/name  \
# 0                   6.9  Profits as % of Stockholder Equity
# 1                   2.0  Profits as % of Stockholder Equity
# 2                   0.4  Profits as % of Stockholder Equity
# 3                   0.3  Profits as % of Stockholder Equity
# 4                   3.9  Profits as % of Stockholder Equity
#
#   tables/2/data/2/value  tables/2/name                     title lists/3/name  \
# 0                  17.5  Profit Ratios                   Walmart          NaN
# 1                   4.6  Profit Ratios                State Grid          NaN
# 2                   1.2  Profit Ratios             Sinopec Group          NaN
# 3                   0.6  Profit Ratios  China National Petroleum          NaN
# 4                  10.7  Profit Ratios              Toyota Motor          NaN
#
#    lists/3/rank
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 62 columns]

# %%
# Get the last five rows
df.tail()
# Out:
#                               highlights/0/description highlights/0/title  \
# 495  Companies are ranked by total revenues for the...      Revenues ($M)
# 496  Companies are ranked by total revenues for the...      Revenues ($M)
# 497  Companies are ranked by total revenues for the...      Revenues ($M)
# 498  Companies are ranked by total revenues for the...      Revenues ($M)
# 499  Companies are ranked by total revenues for the...      Revenues ($M)
#
#      highlights/0/value                           highlights/1/description  \
# 495               21903  Increase/decrease in revenues between the curr...
# 496               21796  Increase/decrease in revenues between the curr...
# 497               21741  Increase/decrease in revenues between the curr...
# 498               21655  Increase/decrease in revenues between the curr...
# 499               21609  Increase/decrease in revenues between the curr...
#
#     highlights/1/title  highlights/1/value  \
# 495     Revenue Change                11.5
# 496     Revenue Change               -13.3
# 497     Revenue Change               -11.3
# 498     Revenue Change                -5.5
# 499     Revenue Change                 3.6
#
#                               highlights/2/description highlights/2/title  \
# 495  Net income after extraordinary charges for a c...       Profits ($M)
# 496  Net income after extraordinary charges for a c...       Profits ($M)
# 497  Net income after extraordinary charges for a c...       Profits ($M)
# 498  Net income after extraordinary charges for a c...       Profits ($M)
# 499  Net income after extraordinary charges for a c...       Profits ($M)
#
#      highlights/2/value                           highlights/3/description  \
# 495               329.0  Total assets on a company's fiscal year-end ba...
# 496               743.9  Total assets on a company's fiscal year-end ba...
# 497               406.4  Total assets on a company's fiscal year-end ba...
# 498              1151.7  Total assets on a company's fiscal year-end ba...
# 499               430.5  Total assets on a company's fiscal year-end ba...
#
#      ...     tables/2/data/0/name  tables/2/data/0/value  \
# 495  ...  Profit as % of Revenues                    1.5
# 496  ...  Profit as % of Revenues                    3.4
# 497  ...  Profit as % of Revenues                    1.9
# 498  ...  Profit as % of Revenues                    5.3
# 499  ...  Profit as % of Revenues                    2.0
#
#        tables/2/data/1/name tables/2/data/1/value  \
# 495  Profits as % of Assets                   0.4
# 496  Profits as % of Assets                   0.7
# 497  Profits as % of Assets                   3.5
# 498  Profits as % of Assets                   7.1
# 499  Profits as % of Assets                   4.3
#
#                    tables/2/data/2/name tables/2/data/2/value  tables/2/name  \
# 495  Profits as % of Stockholder Equity                   1.0  Profit Ratios
# 496  Profits as % of Stockholder Equity                   8.7  Profit Ratios
# 497  Profits as % of Stockholder Equity                   8.0  Profit Ratios
# 498  Profits as % of Stockholder Equity                  38.3  Profit Ratios
# 499  Profits as % of Stockholder Equity                  18.6  Profit Ratios
#
#                               title lists/3/name  lists/3/rank
# 495  Teva Pharmaceutical Industries          NaN           NaN
# 496        New China Life Insurance          NaN           NaN
# 497       Wm. Morrison Supermarkets          NaN           NaN
# 498                             TUI          NaN           NaN
# 499                      AutoNation          NaN           NaN
#
# [5 rows x 62 columns]

# %%
# Get the title column as pandas series
t = df.title
print(t)
# Out:
# 0                             Walmart
# 1                          State Grid
# 2                       Sinopec Group
# 3            China National Petroleum
# 4                        Toyota Motor
#                     ...
# 495    Teva Pharmaceutical Industries
# 496          New China Life Insurance
# 497         Wm. Morrison Supermarkets
# 498                               TUI
# 499                        AutoNation
# Name: title, Length: 500, dtype: object

# %%
# Filter the titles which contain python
python = df[df["title"].str.contains("python")]

python.head()
# Out:
# Empty DataFrame
# Columns: [highlights/0/description, highlights/0/title, highlights/0/value, highlights/1/description, highlights/1/title, highlights/1/value, highlights/2/description, highlights/2/title, highlights/2/value, highlights/3/description, highlights/3/title, highlights/3/value, highlights/4/description, highlights/4/title, highlights/4/value, highlights/5/description, highlights/5/value, highlights/6/value, lists/0/name, lists/0/rank, lists/1/name, lists/1/rank, lists/2/name, lists/2/rank, meta/ceo, meta/industry, meta/previousRank, meta/rank, tables/0/data/0/name, tables/0/data/0/value, tables/0/data/1/name, tables/0/data/1/value, tables/0/data/2/name, tables/0/data/2/value, tables/0/data/3/name, tables/0/data/3/value, tables/0/data/4/name, tables/0/data/4/value, tables/0/data/5/name, tables/0/data/5/value, tables/0/data/6/name, tables/0/data/6/value, tables/0/name, tables/1/data/0/name, tables/1/data/0/value, tables/1/data/1/name, tables/1/data/1/value, tables/1/data/2/name, tables/1/data/2/value, tables/1/data/3/name, tables/1/data/3/value, tables/1/name, tables/2/data/0/name, tables/2/data/0/value, tables/2/data/1/name, tables/2/data/1/value, tables/2/data/2/name, tables/2/data/2/value, tables/2/name, title, lists/3/name, lists/3/rank]
# Index: []
#
# [0 rows x 62 columns]

# %%
# Filter the titles which contain JavaScript
javascript = df[df["title"].str.contains("JavaScript")]
javascript.head()
# Out:
# Empty DataFrame
# Columns: [highlights/0/description, highlights/0/title, highlights/0/value, highlights/1/description, highlights/1/title, highlights/1/value, highlights/2/description, highlights/2/title, highlights/2/value, highlights/3/description, highlights/3/title, highlights/3/value, highlights/4/description, highlights/4/title, highlights/4/value, highlights/5/description, highlights/5/value, highlights/6/value, lists/0/name, lists/0/rank, lists/1/name, lists/1/rank, lists/2/name, lists/2/rank, meta/ceo, meta/industry, meta/previousRank, meta/rank, tables/0/data/0/name, tables/0/data/0/value, tables/0/data/1/name, tables/0/data/1/value, tables/0/data/2/name, tables/0/data/2/value, tables/0/data/3/name, tables/0/data/3/value, tables/0/data/4/name, tables/0/data/4/value, tables/0/data/5/name, tables/0/data/5/value, tables/0/data/6/name, tables/0/data/6/value, tables/0/name, tables/1/data/0/name, tables/1/data/0/value, tables/1/data/1/name, tables/1/data/1/value, tables/1/data/2/name, tables/1/data/2/value, tables/1/data/3/name, tables/1/data/3/value, tables/1/name, tables/2/data/0/name, tables/2/data/0/value, tables/2/data/1/name, tables/2/data/1/value, tables/2/data/2/name, tables/2/data/2/value, tables/2/name, title, lists/3/name, lists/3/rank]
# Index: []
#
# [0 rows x 62 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 62 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   highlights/0/description  500 non-null    object
#  1   highlights/0/title        500 non-null    object
#  2   highlights/0/value        500 non-null    int64
#  3   highlights/1/description  500 non-null    object
#  4   highlights/1/title        500 non-null    object
#  5   highlights/1/value        498 non-null    float64
#  6   highlights/2/description  500 non-null    object
#  7   highlights/2/title        500 non-null    object
#  8   highlights/2/value        499 non-null    float64
#  9   highlights/3/description  500 non-null    object
#  10  highlights/3/title        500 non-null    object
#  11  highlights/3/value        500 non-null    int64
#  12  highlights/4/description  500 non-null    object
#  13  highlights/4/title        500 non-null    object
#  14  highlights/4/value        436 non-null    float64
#  15  highlights/5/description  500 non-null    object
#  16  highlights/5/value        500 non-null    int64
#  17  highlights/6/value        467 non-null    float64
#  18  lists/0/name              196 non-null    object
#  19  lists/0/rank              196 non-null    float64
#  20  lists/1/name              99 non-null     object
#  21  lists/1/rank              99 non-null     float64
#  22  lists/2/name              27 non-null     object
#  23  lists/2/rank              27 non-null     float64
#  24  meta/ceo                  500 non-null    object
#  25  meta/industry             500 non-null    object
#  26  meta/previousRank         500 non-null    int64
#  27  meta/rank                 500 non-null    int64
#  28  tables/0/data/0/name      500 non-null    object
#  29  tables/0/data/0/value     500 non-null    object
#  30  tables/0/data/1/name      500 non-null    object
#  31  tables/0/data/1/value     500 non-null    object
#  32  tables/0/data/2/name      500 non-null    object
#  33  tables/0/data/2/value     500 non-null    object
#  34  tables/0/data/3/name      500 non-null    object
#  35  tables/0/data/3/value     500 non-null    object
#  36  tables/0/data/4/name      500 non-null    object
#  37  tables/0/data/4/value     500 non-null    object
#  38  tables/0/data/5/name      500 non-null    object
#  39  tables/0/data/5/value     500 non-null    int64
#  40  tables/0/data/6/name      500 non-null    object
#  41  tables/0/data/6/value     500 non-null    int64
#  42  tables/0/name             500 non-null    object
#  43  tables/1/data/0/name      500 non-null    object
#  44  tables/1/data/0/value     500 non-null    int64
#  45  tables/1/data/1/name      500 non-null    object
#  46  tables/1/data/1/value     499 non-null    float64
#  47  tables/1/data/2/name      500 non-null    object
#  48  tables/1/data/2/value     500 non-null    int64
#  49  tables/1/data/3/name      500 non-null    object
#  50  tables/1/data/3/value     500 non-null    int64
#  51  tables/1/name             500 non-null    object
#  52  tables/2/data/0/name      500 non-null    object
#  53  tables/2/data/0/value     493 non-null    float64
#  54  tables/2/data/1/name      500 non-null    object
#  55  tables/2/data/1/value     487 non-null    float64
#  56  tables/2/data/2/name      500 non-null    object
#  57  tables/2/data/2/value     488 non-null    float64
#  58  tables/2/name             500 non-null    object
#  59  title                     500 non-null    object
#  60  lists/3/name              1 non-null      object
#  61  lists/3/rank              1 non-null      float64
# dtypes: float64(12), int64(10), object(40)
# memory usage: 242.3+ KB

# %%
df.describe()
# Out:
#        highlights/0/value  highlights/1/value  highlights/2/value  \
# count          500.000000          498.000000          499.000000
# mean         55416.358000            4.538353         3055.203206
# std          45725.478963           28.549067         5171.981071
# min          21609.000000          -67.300000       -13038.000000
# 25%          29003.000000           -5.900000          556.950000
# 50%          40236.000000            0.550000         1761.600000
# 75%          63926.750000            6.975000         3954.000000
# max         485873.000000          442.300000        45687.000000
#
#        highlights/3/value  highlights/4/value  highlights/5/value  \
# count        5.000000e+02          436.000000        5.000000e+02
# mean         2.436323e+05           24.152752        1.339983e+05
# std          4.851937e+05          437.509566        1.700878e+05
# min          3.717000e+03         -793.700000        3.280000e+02
# 25%          3.658850e+04          -22.775000        4.293250e+04
# 50%          7.326150e+04           -0.350000        9.291050e+04
# 75%          1.805640e+05           17.700000        1.689172e+05
# max          3.473238e+06         8909.500000        2.300000e+06
#
#        highlights/6/value   lists/0/rank   lists/1/rank  lists/2/rank  ...  \
# count          467.000000     196.000000      99.000000     27.000000  ...
# mean           237.830835   29125.755102   59606.626263     35.592593  ...
# std            139.211279   45501.876469   49307.241781     29.403374  ...
# min              1.000000       1.000000       1.000000      1.000000  ...
# 25%            117.500000      40.750000      31.500000     13.500000  ...
# 50%            236.000000      88.500000  100000.000000     28.000000  ...
# 75%            355.500000  100000.000000  100000.000000     58.000000  ...
# max            500.000000  100000.000000  100000.000000     99.000000  ...
#
#        tables/0/data/5/value  tables/0/data/6/value  tables/1/data/0/value  \
# count             500.000000           5.000000e+02             500.000000
# mean               15.036000           1.339983e+05           55416.358000
# std                 7.932752           1.700878e+05           45725.478963
# min                 1.000000           3.280000e+02           21609.000000
# 25%                 7.000000           4.293250e+04           29003.000000
# 50%                17.000000           9.291050e+04           40236.000000
# 75%                23.000000           1.689172e+05           63926.750000
# max                23.000000           2.300000e+06          485873.000000
#
#        tables/1/data/1/value  tables/1/data/2/value  tables/1/data/3/value  \
# count             499.000000           5.000000e+02             500.000000
# mean             3055.203206           2.436323e+05           30628.076000
# std              5171.981071           4.851937e+05           43642.576833
# min            -13038.000000           3.717000e+03          -59909.000000
# 25%               556.950000           3.658850e+04            7553.750000
# 50%              1761.600000           7.326150e+04           15809.500000
# 75%              3954.000000           1.805640e+05           37828.500000
# max             45687.000000           3.473238e+06          301893.000000
#
#        tables/2/data/0/value  tables/2/data/1/value  tables/2/data/2/value  \
# count             493.000000             487.000000             488.000000
# mean                5.652130               3.115606              16.684221
# std                 7.790644               4.401207              52.896765
# min               -40.100000             -23.700000            -160.300000
# 25%                 1.400000               0.700000               5.900000
# 50%                 3.800000               2.300000              10.000000
# 75%                 8.100000               4.700000              15.800000
# max                46.100000              23.700000             847.200000
#
#        lists/3/rank
# count           1.0
# mean            4.0
# std             NaN
# min             4.0
# 25%             4.0
# 50%             4.0
# 75%             4.0
# max             4.0
#
# [8 rows x 22 columns]
