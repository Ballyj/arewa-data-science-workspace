# %% [markdown]
# # Exercise: Strings

# %%
concatenate = 'Thirty ' + 'Days ' + 'Of ' + 'Python'
print(concatenate)
concatenate2 = 'Coding ' + 'For ' + 'All'
print(concatenate2)

company = "Coding for all"
print(company)
print(len(company))
print(company.lower())
print(company.capitalize())
print(company.swapcase())
print(company.title ())
print(company[0:6])
print(company.find('Coding'))
print(company.replace("Coding", "Python"))
print(company.replace("all", "Everyone"))
print(company.split())
socail_media = 'Facebook Google Microsoft Apple IBM Oracle Amazon'
print(socail_media.split())
print(company[0:7:11])
print(company.index('C'))
print(company.index('f'))
print(company.rfind("i"))

sentence = "You cannot end a sentence with because, because is a conjunction"
print(sentence.index("because"))
print(sentence.rindex("because"))
print(sentence[31:49])
print(sentence.find("because"))
print(company.startswith('Coding'))

indent = '30DaysOfPython'
print(indent.isidentifier()) 
indent2 = 'thirty_days_of_python'
print(indent2.isidentifier()) 

python = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
result = '# '.join(python)
print(result)

print('I am enjoying this challenge. \nI just wonder what is next.')

print("Name \tAge \tCountry \tCity")
print("Ntong \t36 \tNigeria \tKaduna")

raduis = 10
area = 3.14 * raduis ** 2
print('The area of a circle with a raduis %d is %.2f meters square' %(raduis, area))

a,b = 8,6
print('{} + {} = {}'.format(a,b, a + b))
print('{} - {} = {}'.format(a,b, a - b))
print('{} * {} = {}'.format(a,b, a * b))
print('{} / {} = {:.3f}'.format(a,b, a / b))
print('{} % {} = {}'.format(a,b, a % b))
print('{} // {} = {}'.format(a,b, a // b))
print('{} ** {} = {}'.format(a,b, a ** b))
# Out:
# Thirty Days Of Python
# Coding For All
# Coding for all
# 14
# coding for all
# Coding for all
# cODING FOR ALL
# Coding For All
# Coding
# 0
# Python for all
# Coding for Everyone
# ['Coding', 'for', 'all']
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
# C
# 0
# 7
# 3
# 31
# 40
# because, because i
# 31
# True
# False
# True
# Django# Flask# Bottle# Pyramid# Falcon
# I am enjoying this challenge.
# I just wonder what is next.
# Name 	Age 	Country 	City
# Ntong 	36 	Nigeria 	Kaduna
# The area of a circle with a raduis 10 is 314.00 meters square
# 8 + 6 = 14
# 8 - 6 = 2
# 8 * 6 = 48
# 8 / 6 = 1.333
# 8 % 6 = 2
# 8 // 6 = 1
# 8 ** 6 = 262144
