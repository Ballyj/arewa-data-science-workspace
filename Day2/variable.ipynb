# %%
# Day 2: 30 Days of python programming 
first_name = "Jonathan"
last_name = "Bala"
full_name = "Bala Jonathan"
country = "Nigeria"
city = "Kaduna"
age = "36"
year = 2023
is_true = True
is_light_on = True
first_name, last_name, country, age, is_light_on, is_married = "Jonathan", "Bala", "Nigeria", 36, True, False
print("First name: ", first_name)
print("Last name: ", last_name)
print("Full name: "), full_name 
print("My Country: ", country   )
print("My City: ", city)
print("My Age: ", age)
print("Year: ", year)
print("Is the Light on? ", is_light_on)
print("Is it True: ", is_true)

# Exercise 2

print(type(first_name   ))
print(type(last_name    ))
print(type(full_name    ))
print(type(country))
print(type(city))
print(type(age))
print(type(year))
print(type(is_light_on))
print(type(is_true  ))

print(len(first_name) == len(last_name))
# Out:
# First name:  Jonathan
# Last name:  Bala
# Full name:
# My Country:  Nigeria
# My City:  Kaduna
# My Age:  36
# Year:  2023
# Is the Light on?  True
# Is it True:  True
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>
# <class 'bool'>
# False

# %% [markdown]
# # Level Two

# %%
num_one = 5
num_two = 4
total = num_one + num_two
print(total)

product = num_one * num_two
print(product   )

division = num_one / num_two
print(division)

remainder = num_one % num_two
print(remainder )

exponentail = num_one ** num_two
print(exponentail)


radius = 30
pi = 3.14
area_of_circle = pi * (radius ** 2) 
print(area_of_circle)

circumference_of_circle = 2 * pi * radius
print(circumference_of_circle)

first_name = input("Enter your first name: ")
last_name = input("Enter your Last name: ")
age = input("How old are you? ")
country = input("What is your country? ")
print(first_name)
print(last_name)
print(age)
print(country)

# %%
help(dict)
help(list)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Built-in subclasses:
#  |      StgDict
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
# ...
